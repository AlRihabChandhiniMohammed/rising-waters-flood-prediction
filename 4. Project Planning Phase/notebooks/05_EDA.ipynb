# %% [markdown]
# # 05 — Exploratory Data Analysis
#
# Analyze data distributions, correlations, and patterns.
# <!-- TODO: Add EDA visualizations and summary statistics -->

# %%
import pandas as pd

# %%
df = pd.read_excel("../../3. Project Design Phase/dataset/raw/flood dataset.xlsx")

# %%
df.isnull().sum()
# Out:
# Temp           0
# Humidity       0
# Cloud Cover    0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# avgjune        0
# sub            0
# flood          0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Temp           False
# Humidity       False
# Cloud Cover    False
# ANNUAL         False
# Jan-Feb        False
# Mar-May        False
# Jun-Sep        False
# Oct-Dec        False
# avgjune        False
# sub            False
# flood          False
# dtype: bool

# %% [markdown]
# ## Observation
#
# The missing value analysis shows that all columns contain **0 missing values**, indicating that the dataset is complete. The `isnull().sum()` function confirms that there are no null entries in any feature, while `isnull().any()` returns **False** for every column, verifying the absence of missing data. Therefore, no missing value treatment or imputation is required before proceeding with model development.
